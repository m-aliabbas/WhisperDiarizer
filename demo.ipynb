# %%
a=[{'start': 0.0, 'end': 1.0, 'text': ' Hello?', 'speaker': 'SPEAKER 1'}, {'start': 1.0, 'end': 2.0, 'text': ' Hello?', 'speaker': 'SPEAKER 1'}, {'start': 2.0, 'end': 7.0, 'text': ' My name is Becky from Senior Benefits.', 'speaker': 'SPEAKER 1'}, {'start': 7.0, 'end': 8.0, 'text': ' How are you today?', 'speaker': 'SPEAKER 1'}, {'start': 8.0, 'end': 11.0, 'text': ' Are you a live person or a recording?', 'speaker': 'SPEAKER 1'}, {'start': 11.0, 'end': 13.0, 'text': " Yeah, I'm a real person.", 'speaker': 'SPEAKER 1'}, {'start': 13.0, 'end': 16.0, 'text': " I'm just talking to you through a computer.", 'speaker': 'SPEAKER 1'}, {'start': 16.0, 'end': 19.0, 'text': ' So there might be just a little bit of delay on the line.', 'speaker': 'SPEAKER 1'}, {'start': 19.0, 'end': 25.0, 'text': ' Um, is there any way you can remove me from the call list?', 'speaker': 'SPEAKER 1'}, {'start': 25.0, 'end': 26.0, 'text': " Yes, ma'am.", 'speaker': 'SPEAKER 1'}, {'start': 26.0, 'end': 32.0, 'text': " I'm not Medicare eligible, and I keep getting like five to six phone calls a day,", 'speaker': 'SPEAKER 1'}, {'start': 32.0, 'end': 34.0, 'text': " and it's quite annoying.", 'speaker': 'SPEAKER 1'}, {'start': 34.0, 'end': 37.0, 'text': ' Yeah, there might be companies calling around.', 'speaker': 'SPEAKER 1'}, {'start': 37.0, 'end': 38.0, 'text': " I'm pretty sure that wasn't us.", 'speaker': 'SPEAKER 1'}, {'start': 38.0, 'end': 40.0, 'text': ' So now this will only take a few minutes of your time,', 'speaker': 'SPEAKER 1'}, {'start': 40.0, 'end': 45.0, 'text': ' and I just want to make sure you get all the details about the new final expense plan.', 'speaker': 'SPEAKER 1'}, {'start': 45.0, 'end': 46.0, 'text': ' Okay?', 'speaker': 'SPEAKER 1'}, {'start': 46.0, 'end': 47.0, 'text': " It doesn't matter.", 'speaker': 'SPEAKER 1'}, {'start': 47.0, 'end': 48.0, 'text': " I'm not eligible.", 'speaker': 'SPEAKER 1'}, {'start': 48.0, 'end': 49.0, 'text': ' Okay.', 'speaker': 'SPEAKER 1'}, {'start': 49.0, 'end': 52.0, 'text': ' How old are you right now?', 'speaker': 'SPEAKER 1'}, {'start': 52.0, 'end': 56.0, 'text': ' I am 58 years old.', 'speaker': 'SPEAKER 1'}, {'start': 56.0, 'end': 57.0, 'text': ' Awesome.', 'speaker': 'SPEAKER 1'}, {'start': 57.0, 'end': 59.0, 'text': " You're qualifying just fine.", 'speaker': 'SPEAKER 1'}, {'start': 59.0, 'end': 64.0, 'text': ' So let me quickly bring my associate on the line who will pass you with the license agent,', 'speaker': 'SPEAKER 1'}, {'start': 64.0, 'end': 68.0, 'text': ' and they will tell you exactly what kind of benefits you qualify for today.', 'speaker': 'SPEAKER 1'}, {'start': 68.0, 'end': 70.0, 'text': ' Okay?', 'speaker': 'SPEAKER 1'}, {'start': 70.0, 'end': 72.0, 'text': ' Sure.', 'speaker': 'SPEAKER 1'}, {'start': 72.0, 'end': 75.0, 'text': ' Just a second.', 'speaker': 'SPEAKER 1'}, {'start': 75.0, 'end': 79.0, 'text': ' Thank you for connecting with General Insurance Scouts.', 'speaker': 'SPEAKER 1'}, {'start': 79.0, 'end': 80.0, 'text': ' This is Michael.', 'speaker': 'SPEAKER 1'}, {'start': 80.0, 'end': 82.0, 'text': ' How are you doing?', 'speaker': 'SPEAKER 1'}, {'start': 82.0, 'end': 84.0, 'text': " I'm fine.", 'speaker': 'SPEAKER 1'}, {'start': 84.0, 'end': 85.0, 'text': ' Glad to hear.', 'speaker': 'SPEAKER 1'}, {'start': 85.0, 'end': 86.0, 'text': ' God bless you.', 'speaker': 'SPEAKER 1'}, {'start': 86.0, 'end': 88.0, 'text': ' And give you a long life.', 'speaker': 'SPEAKER 1'}, {'start': 88.0, 'end': 91.0, 'text': " Ma'am, as you know, this call list,", 'speaker': 'SPEAKER 1'}, {'start': 91.0, 'end': 93.0, 'text': ' will only take a few minutes of your time,', 'speaker': 'SPEAKER 1'}, {'start': 93.0, 'end': 95.0, 'text': ' and it will only take a few minutes of your time,', 'speaker': 'SPEAKER 1'}, {'start': 95.0, 'end': 97.0, 'text': ' and it will only take a few minutes of your time,', 'speaker': 'SPEAKER 1'}, {'start': 97.0, 'end': 99.0, 'text': ' and it will only take a few minutes of your time,', 'speaker': 'SPEAKER 2'}]

# %%
import pandas as pd

# %%
df = pd.DataFrame(a)

# %%
df
# Out:
#     start   end                                               text    speaker
# 0     0.0   1.0                                             Hello?  SPEAKER 1
# 1     1.0   2.0                                             Hello?  SPEAKER 1
# 2     2.0   7.0             My name is Becky from Senior Benefits.  SPEAKER 1
# 3     7.0   8.0                                 How are you today?  SPEAKER 1
# 4     8.0  11.0              Are you a live person or a recording?  SPEAKER 1
# 5    11.0  13.0                           Yeah, I'm a real person.  SPEAKER 1
# 6    13.0  16.0        I'm just talking to you through a computer.  SPEAKER 1
# 7    16.0  19.0   So there might be just a little bit of delay ...  SPEAKER 1
# 8    19.0  25.0   Um, is there any way you can remove me from t...  SPEAKER 1
# 9    25.0  26.0                                        Yes, ma'am.  SPEAKER 1
# 10   26.0  32.0   I'm not Medicare eligible, and I keep getting...  SPEAKER 1
# ...

# %%
b=[{'start': 0.0, 'end': 1.0, 'text': ' Hello.', 'speaker': 'SPEAKER 2'}, {'start': 1.0, 'end': 2.0, 'text': ' Hi.', 'speaker': 'SPEAKER 2'}, {'start': 2.0, 'end': 3.0, 'text': ' Hi.', 'speaker': 'SPEAKER 2'}, {'start': 3.0, 'end': 4.0, 'text': ' My name is Becky.', 'speaker': 'SPEAKER 2'}, {'start': 4.0, 'end': 6.0, 'text': " I'm calling you from Senior Benefits on Recreate Line.", 'speaker': 'SPEAKER 2'}, {'start': 6.0, 'end': 8.0, 'text': ' How are you?', 'speaker': 'SPEAKER 2'}, {'start': 8.0, 'end': 10.0, 'text': ' Okay.', 'speaker': 'SPEAKER 2'}, {'start': 10.0, 'end': 11.0, 'text': ' Great.', 'speaker': 'SPEAKER 2'}, {'start': 11.0, 'end': 13.0, 'text': " I'm with American Benefits.", 'speaker': 'SPEAKER 2'}, {'start': 13.0, 'end': 17.0, 'text': " So based on the records, I'm sure that human qualify for state-regulated", 'speaker': 'SPEAKER 2'}, {'start': 17.0, 'end': 19.0, 'text': ' final expense life insurance plan.', 'speaker': 'SPEAKER 2'}, {'start': 19.0, 'end': 22.0, 'text': ' Now to generate the best pricing for your age.', 'speaker': 'SPEAKER 2'}, {'start': 22.0, 'end': 24.0, 'text': " I'm not interested in any insurance.", 'speaker': 'SPEAKER 1'}, {'start': 24.0, 'end': 25.0, 'text': ' Thank you.', 'speaker': 'SPEAKER 1'}, {'start': 25.0, 'end': 26.0, 'text': " We're covered.", 'speaker': 'SPEAKER 1'}, {'start': 26.0, 'end': 27.0, 'text': ' Bye.', 'speaker': 'SPEAKER 1'}]

# %%
df2 = pd.DataFrame(b)

# %%
df2
# Out:
#     start   end                                               text    speaker
# 0     0.0   1.0                                             Hello.  SPEAKER 2
# 1     1.0   2.0                                                Hi.  SPEAKER 2
# 2     2.0   3.0                                                Hi.  SPEAKER 2
# 3     3.0   4.0                                  My name is Becky.  SPEAKER 2
# 4     4.0   6.0   I'm calling you from Senior Benefits on Recre...  SPEAKER 2
# 5     6.0   8.0                                       How are you?  SPEAKER 2
# 6     8.0  10.0                                              Okay.  SPEAKER 2
# 7    10.0  11.0                                             Great.  SPEAKER 2
# 8    11.0  13.0                        I'm with American Benefits.  SPEAKER 2
# 9    13.0  17.0   So based on the records, I'm sure that human ...  SPEAKER 2
# 10   17.0  19.0                 final expense life insurance plan.  SPEAKER 2
# ...

# %%
c = [{'start': 0.0, 'end': 1.0, 'text': ' Hello.', 'speaker': 'SPEAKER 2'}, {'start': 1.0, 'end': 2.0, 'text': ' Hello.', 'speaker': 'SPEAKER 2'}, {'start': 2.0, 'end': 3.0, 'text': " How's it going?", 'speaker': 'SPEAKER 2'}, {'start': 3.0, 'end': 4.0, 'text': " I think it's that key.", 'speaker': 'SPEAKER 2'}, {'start': 4.0, 'end': 7.0, 'text': " I'll call in you from Senior Benefits and we're quite annoying.", 'speaker': 'SPEAKER 2'}, {'start': 7.0, 'end': 8.0, 'text': ' How are you?', 'speaker': 'SPEAKER 2'}, {'start': 8.0, 'end': 10.0, 'text': ' Okay.', 'speaker': 'SPEAKER 2'}, {'start': 10.0, 'end': 11.0, 'text': ' Great.', 'speaker': 'SPEAKER 2'}, {'start': 11.0, 'end': 13.0, 'text': " I'm with American Benefits.", 'speaker': 'SPEAKER 2'}, {'start': 13.0, 'end': 17.0, 'text': " So based on the records, I'm sure that if you may qualify for state-driven related final", 'speaker': 'SPEAKER 2'}, {'start': 17.0, 'end': 19.0, 'text': ' exams, life insurance plan.', 'speaker': 'SPEAKER 2'}, {'start': 19.0, 'end': 22.0, 'text': ' Now to generate the best pricing for your age.', 'speaker': 'SPEAKER 2'}, {'start': 22.0, 'end': 24.0, 'text': ' Time that interested in any insurance.', 'speaker': 'SPEAKER 1'}, {'start': 24.0, 'end': 25.0, 'text': ' Thank you.', 'speaker': 'SPEAKER 1'}, {'start': 25.0, 'end': 26.0, 'text': " We've got work covered.", 'speaker': 'SPEAKER 1'}, {'start': 26.0, 'end': 27.0, 'text': ' Bye.', 'speaker': 'SPEAKER 1'}]
df3 = pd.DataFrame(c)

# %%
df3
# Out:
#     start   end                                               text    speaker
# 0     0.0   1.0                                             Hello.  SPEAKER 2
# 1     1.0   2.0                                             Hello.  SPEAKER 2
# 2     2.0   3.0                                    How's it going?  SPEAKER 2
# 3     3.0   4.0                             I think it's that key.  SPEAKER 2
# 4     4.0   7.0   I'll call in you from Senior Benefits and we'...  SPEAKER 2
# 5     7.0   8.0                                       How are you?  SPEAKER 2
# 6     8.0  10.0                                              Okay.  SPEAKER 2
# 7    10.0  11.0                                             Great.  SPEAKER 2
# 8    11.0  13.0                        I'm with American Benefits.  SPEAKER 2
# 9    13.0  17.0   So based on the records, I'm sure that if you...  SPEAKER 2
# 10   17.0  19.0                        exams, life insurance plan.  SPEAKER 2
# ...

# %%
base=[{'start': 0.0, 'end': 11.36, 'text': ' Hello, my name is Becky from Senior Benefits, how are you today?', 'speaker': 'SPEAKER 1'}, {'start': 11.36, 'end': 13.84, 'text': ' Are you a live person or a recording?', 'speaker': 'SPEAKER 1'}, {'start': 13.84, 'end': 19.84, 'text': " Yeah, I'm a real person, I'm just talking to you through a computer, so there might be", 'speaker': 'SPEAKER 1'}, {'start': 19.84, 'end': 23.76, 'text': ' just a little bit of delay on the line.', 'speaker': 'SPEAKER 1'}, {'start': 23.76, 'end': 27.68, 'text': ' Is there any way you can remove me from the call list?', 'speaker': 'SPEAKER 1'}, {'start': 28.4, 'end': 30.16, 'text': " Yes, ma'am.", 'speaker': 'SPEAKER 1'}, {'start': 30.16, 'end': 38.0, 'text': " I'm not Medicare eligible, and I keep getting like five to six phone calls a day and it's quite annoying.", 'speaker': 'SPEAKER 1'}, {'start': 39.28, 'end': 42.64, 'text': " Yeah, there are many companies calling around, I'm pretty sure that wasn't us,", 'speaker': 'SPEAKER 1'}, {'start': 42.64, 'end': 47.36, 'text': ' so now this will only take a few minutes off your time, and I just want to make sure you get all', 'speaker': 'SPEAKER 1'}, {'start': 47.36, 'end': 52.879999999999995, 'text': " the details about the new final expense plan. Okay? It doesn't matter, I'm not eligible.", 'speaker': 'SPEAKER 1'}, {'start': 52.88, 'end': 60.56, 'text': ' Okay, how old are you right now? I am 58 years old.', 'speaker': 'SPEAKER 1'}, {'start': 63.120000000000005, 'end': 68.32000000000001, 'text': " Awesome, you're qualifying just fine, so let me quickly bring my associate on the line", 'speaker': 'SPEAKER 1'}, {'start': 68.32000000000001, 'end': 73.76, 'text': ' who will pass you with the license agent and they will tell you exactly what kind of benefit', 'speaker': 'SPEAKER 1'}, {'start': 73.76, 'end': 80.4, 'text': ' you qualify for today. Okay? Sure. Just a second.', 'speaker': 'SPEAKER 1'}, {'start': 80.48, 'end': 87.68, 'text': ' Thank you for connecting with UNROL insurance scopes, this is Michael Haigidoen.', 'speaker': 'SPEAKER 1'}, {'start': 89.28, 'end': 94.80000000000001, 'text': ' And fine. Glad to hear you, God bless you, and give you a long life.', 'speaker': 'SPEAKER 1'}, {'start': 95.84, 'end': 97.28, 'text': " Ma'am, as you know, the squad", 'speaker': 'SPEAKER 2'}]
df5 = pd.DataFrame(base)

# %%
df5
# Out:
#     start    end                                               text    speaker
# 0    0.00  11.36   Hello, my name is Becky from Senior Benefits,...  SPEAKER 1
# 1   11.36  13.84              Are you a live person or a recording?  SPEAKER 1
# 2   13.84  19.84   Yeah, I'm a real person, I'm just talking to ...  SPEAKER 1
# 3   19.84  23.76            just a little bit of delay on the line.  SPEAKER 1
# 4   23.76  27.68   Is there any way you can remove me from the c...  SPEAKER 1
# 5   28.40  30.16                                        Yes, ma'am.  SPEAKER 1
# 6   30.16  38.00   I'm not Medicare eligible, and I keep getting...  SPEAKER 1
# 7   39.28  42.64   Yeah, there are many companies calling around...  SPEAKER 1
# 8   42.64  47.36   so now this will only take a few minutes off ...  SPEAKER 1
# 9   47.36  52.88   the details about the new final expense plan....  SPEAKER 1
# 10  52.88  60.56   Okay, how old are you right now? I am 58 year...  SPEAKER 1
# ...
